# %% [markdown]
# # Testing Connection to Google Sheets

# %%
import numpy as np
import pandas as pd
import re
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io

#Custom module
#import jsmith_acquire

# %% [markdown]
# # Read In OLS Case PDF
#
# Start with just the first page. Break it down and gather the available info.

# %%
#Set up the pdf path
pdf_path = '/Users/johnathonsmith/Downloads/MAV_OLS_Pending.pdf'

# %%
#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page_number, page in enumerate(PDFPage.get_pages(fh, caching=True, maxpages = 70, check_extractable=True)):
        #Process the current page
        #Only read page 1 for now (index = 0)
        if page_number == 67:
            page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

print(text)
# Out:
#                                      CRIMINAL DETAILED PENDING CASES REPORT - 09/12/2024
#                                              MAVERICK - COUNTY CLERK - OLS COURT
#                               FILED PENDING CASES AS OF 09/12/2024 - SORTED BY FILE DATE - PAGE 68
#
# CAUSE #                  FILE DT  DEFENDANT'S NAME                      COURT   DOCKET DT  OUTSTANDING WARRANTS
#    ACTIVE ATTORNEY/S               1ST OFFENSE                            ST RPT COLUMN
#
# 36624                 08/16/2024  RIOS ROBLES, WILMARY CAROLINA         OLS
#    NEUBIG, EMILY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36625                 08/16/2024  GARCES CANCHINGRE, ALEX SEBASTION     OLS    09/30/2024
#    TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36626                 08/16/2024  MEDINA BETANCOURT, JUNIOR ALEXANDER   OLS
#    TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36627                 08/16/2024  DA COSTA, FELIPE DAVIDSON             OLS
#    TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36628                 08/16/2024  QUIROZ BAUTISTA, YULISA AIDEE         OLS    09/30/2024
#    CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV
#                                    CONV OR SBI
# 36629                 08/16/2024  LOREDO RODRIGUEZ, JOSE JAVIER         OLS    09/30/2024
#    CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV
#                                    CONV OR SBI
# 36630                 08/16/2024  GARCIA DE, ROSARIO                    OLS    09/30/2024
#    CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV
#                                    CONV OR SBI
# 36631                 08/19/2024  VILLALOBOS MARTINEZ, ABRAHAM          OLS
#    ESPARZA, ILLIANA                EVADING ARREST DETENTION               OTHER MISDEMEANOR
# 36645                 08/23/2024  ZARZA RIOS, LEYDI ESTEFANI            OLS
#                                    CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36646                 08/26/2024  TERAN PEREZ, FRANCISCO DAVID          OLS
#    GARCIA, MICHAEL                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36647                 08/28/2024  ACUNA ROMERO, LUIS ERNESTO            OLS
#    THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36648                 08/28/2024  BARBERENA BUSTOS, JOSE RAMON          OLS
#    THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36649                 08/30/2024  MOHENO SANCHEZ, YANS                  OLS
#    MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR
#                                    HABIT/SHLTR/SUPRFUND/INFSTRT
# 36650                 08/30/2024  DIAZ ALVAREZ, JOSE JULIAN             OLS
#    MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR
#                                    HABIT/SHLTR/SUPRFUND/INFSTRT
# 36651                 09/04/2024  PAUCAR SUNTAXI, ALEX WLADIMIR         OLS
#    THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36652                 09/04/2024  CARMO SILVA, WEMERSON                 OLS
#    THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR
# 36653                 09/04/2024  MIRANDA MILER, GEISE KELLY            OLS

# %%
print(repr(text))
# Out:
# "                                     CRIMINAL DETAILED PENDING CASES REPORT - 09/12/2024\n                                             MAVERICK - COUNTY CLERK - OLS COURT\n                              FILED PENDING CASES AS OF 09/12/2024 - SORTED BY FILE DATE - PAGE 68\n\nCAUSE #                  FILE DT  DEFENDANT'S NAME                      COURT   DOCKET DT  OUTSTANDING WARRANTS\n   ACTIVE ATTORNEY/S               1ST OFFENSE                            ST RPT COLUMN                                       \n\n36624                 08/16/2024  RIOS ROBLES, WILMARY CAROLINA         OLS                                    \n   NEUBIG, EMILY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36625                 08/16/2024  GARCES CANCHINGRE, ALEX SEBASTION     OLS    09/30/2024                      \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36626                 08/16/2024  MEDINA BETANCOURT, JUNIOR ALEXANDER   OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36627                 08/16/2024  DA COSTA, FELIPE DAVIDSON             OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36628                 08/16/2024  QUIROZ BAUTISTA, YULISA AIDEE         OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36629                 08/16/2024  LOREDO RODRIGUEZ, JOSE JAVIER         OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36630                 08/16/2024  GARCIA DE, ROSARIO                    OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36631                 08/19/2024  VILLALOBOS MARTINEZ, ABRAHAM          OLS                                    \n   ESPARZA, ILLIANA                EVADING ARREST DETENTION               OTHER MISDEMEANOR                                   \n36645                 08/23/2024  ZARZA RIOS, LEYDI ESTEFANI            OLS                                    \n                                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36646                 08/26/2024  TERAN PEREZ, FRANCISCO DAVID          OLS                                    \n   GARCIA, MICHAEL                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36647                 08/28/2024  ACUNA ROMERO, LUIS ERNESTO            OLS                                    \n   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36648                 08/28/2024  BARBERENA BUSTOS, JOSE RAMON          OLS                                    \n   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36649                 08/30/2024  MOHENO SANCHEZ, YANS                  OLS                                    \n   MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR   ...

# %%
#Separate the header from the body
header = text[:500]
header
# Out:
# "                                     CRIMINAL DETAILED PENDING CASES REPORT - 09/12/2024\n                                             MAVERICK - COUNTY CLERK - OLS COURT\n                              FILED PENDING CASES AS OF 09/12/2024 - SORTED BY FILE DATE - PAGE 68\n\nCAUSE #                  FILE DT  DEFENDANT'S NAME                      COURT   DOCKET DT  OUTSTANDING WARRANTS\n   ACTIVE ATTORNEY/S               1ST OFFENSE                            ST RPT COLUMN                               "

# %%
#body 
body = text[500:]
body
# Out:
# '        \n\n36624                 08/16/2024  RIOS ROBLES, WILMARY CAROLINA         OLS                                    \n   NEUBIG, EMILY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36625                 08/16/2024  GARCES CANCHINGRE, ALEX SEBASTION     OLS    09/30/2024                      \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36626                 08/16/2024  MEDINA BETANCOURT, JUNIOR ALEXANDER   OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36627                 08/16/2024  DA COSTA, FELIPE DAVIDSON             OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36628                 08/16/2024  QUIROZ BAUTISTA, YULISA AIDEE         OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36629                 08/16/2024  LOREDO RODRIGUEZ, JOSE JAVIER         OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36630                 08/16/2024  GARCIA DE, ROSARIO                    OLS    09/30/2024                      \n   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          \n                                   CONV OR SBI                                                                                \n36631                 08/19/2024  VILLALOBOS MARTINEZ, ABRAHAM          OLS                                    \n   ESPARZA, ILLIANA                EVADING ARREST DETENTION               OTHER MISDEMEANOR                                   \n36645                 08/23/2024  ZARZA RIOS, LEYDI ESTEFANI            OLS                                    \n                                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36646                 08/26/2024  TERAN PEREZ, FRANCISCO DAVID          OLS                                    \n   GARCIA, MICHAEL                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36647                 08/28/2024  ACUNA ROMERO, LUIS ERNESTO            OLS                                    \n   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36648                 08/28/2024  BARBERENA BUSTOS, JOSE RAMON          OLS                                    \n   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n36649                 08/30/2024  MOHENO SANCHEZ, YANS                  OLS                                    \n   MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR                                   \n                                   HABIT/SHLTR/SUPRFUND/INFSTRT                                                               \n36650                 08/30/2024  DIAZ ALVAREZ, JOSE JULIAN             OLS                                    \n   MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR                                   \n                                   HABIT/SHLTR/SUPRFUND/INFSTRT                                       ...

# %%
#Remove leading and trailing whitespace
body = body.strip()

# %%
#Try splitting the cases up on the new lines
cases = body.split('\n')

# %%
#How many cases per page? (in the detailed report, there are more new lines than cases)
len(cases)
# Out:
# 38

# %%
cases
# Out:
# ['36624                 08/16/2024  RIOS ROBLES, WILMARY CAROLINA         OLS                                    ',
#  '   NEUBIG, EMILY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36625                 08/16/2024  GARCES CANCHINGRE, ALEX SEBASTION     OLS    09/30/2024                      ',
#  '   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36626                 08/16/2024  MEDINA BETANCOURT, JUNIOR ALEXANDER   OLS                                    ',
#  '   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36627                 08/16/2024  DA COSTA, FELIPE DAVIDSON             OLS                                    ',
#  '   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36628                 08/16/2024  QUIROZ BAUTISTA, YULISA AIDEE         OLS    09/30/2024                      ',
#  '   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          ',
#  '                                   CONV OR SBI                                                                                ',
#  '36629                 08/16/2024  LOREDO RODRIGUEZ, JOSE JAVIER         OLS    09/30/2024                      ',
#  '   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          ',
#  '                                   CONV OR SBI                                                                                ',
#  '36630                 08/16/2024  GARCIA DE, ROSARIO                    OLS    09/30/2024                      ',
#  '   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          ',
#  '                                   CONV OR SBI                                                                                ',
#  '36631                 08/19/2024  VILLALOBOS MARTINEZ, ABRAHAM          OLS                                    ',
#  '   ESPARZA, ILLIANA                EVADING ARREST DETENTION               OTHER MISDEMEANOR                                   ',
#  '36645                 08/23/2024  ZARZA RIOS, LEYDI ESTEFANI            OLS                                    ',
#  '                                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36646                 08/26/2024  TERAN PEREZ, FRANCISCO DAVID          OLS                                    ',
#  '   GARCIA, MICHAEL                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36647                 08/28/2024  ACUNA ROMERO, LUIS ERNESTO            OLS                                    ',
#  '   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36648                 08/28/2024  BARBERENA BUSTOS, JOSE RAMON          OLS                                    ',
#  '   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36649                 08/30/2024  MOHENO SANCHEZ, YANS                  OLS                                    ',
#  '   MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR                                   ',
#  '                                   HABIT/SHLTR/SUPRFUND/INFSTRT                                                               ',
#  '36650                 08/30/2024  DIAZ ALVAREZ, JOSE JULIAN             OLS                                    ',
#  '   MARES, ALFREDO                  CRIM TRESPASS                          OTHER MISDEMEANOR                                   ',
#  '                                   HABIT/SHLTR/SUPRFUND/INFSTRT                                                               ',
#  '36651                 09/04/2024  PAUCAR SUNTAXI, ALEX WLADIMIR         OLS                                    ',
#  '   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36652                 09/04/2024  CARMO SILVA, WEMERSON                 OLS                                    ',
#  '   THOMAS, JANAE                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   ',
#  '36653                 09/04/2024  MIRANDA MILER, GEISE KELLY            OLS']

# %%
#Just work with the first line for now
case = cases[8]
case
# Out:
# '36628                 08/16/2024  QUIROZ BAUTISTA, YULISA AIDEE         OLS    09/30/2024                      '

# %% [markdown]
# # Gather Info For a Single Case

# %% [markdown]
# __Cause Number__

# %%
#Gather the cause number
cause_num = case[:22].strip()
cause_num
# Out:
# '36628'

# %% [markdown]
# __File Date__

# %%
#Gather the file date
file_date = case[22:34].strip()
file_date
# Out:
# '08/16/2024'

# %% [markdown]
# __Defendant Name__

# %%
defendant_name = case[34:72].strip()
defendant_name
# Out:
# 'QUIROZ BAUTISTA, YULISA AIDEE'

# %% [markdown]
# __Court__

# %%
court = case[72:79].strip()
court
# Out:
# 'OLS'

# %% [markdown]
# __Docket Date__

# %%
docket_date = case[79:89].strip()
docket_date
# Out:
# '09/30/2024'

# %% [markdown]
# __Outstanding Warrants__

# %%
#Everything after the docket date
warrants = case[89:].strip()
warrants
# Out:
# ''

# %% [markdown]
# __Attorney__

# %%
#The following information is found on subsequent lines due to the way the report is formatted.
#Use a case with all 3 pieces of info
case = cases[9]
case
# Out:
# '   CHAVEZ, JONATHAN                EVADE ARR DET W/VEH/WTRCFT W/PREV                                                          '

# %%
attorney = case[:35].strip()
attorney
# Out:
# 'CHAVEZ, JONATHAN'

# %% [markdown]
# __First Offense__

# %%
offense = case[35:74].strip()
offense
# Out:
# 'EVADE ARR DET W/VEH/WTRCFT W/PREV'

# %% [markdown]
# __ST RPT Column__

# %%
st_rpt = case[74:].strip()
st_rpt
# Out:
# ''

# %% [markdown]
# # Load The First Two Pages
#
# Using the first two pages, set up a loop to gather all the info for each case and create a dataframe.

# %%
#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page in PDFPage.get_pages(fh, caching=True, maxpages = 2, check_extractable=True):
        #Process the current page
        page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

#print(text)

# %%
#Separate the first header from the body
#We'll use this to identify the county later
header = text[:500]

# %%
#body
body = text[500:]

# %%
#Remove leading and trailing whitespaces from the body text
body = body.strip()

# %%
header
# Out:
# "                                     CRIMINAL DETAILED PENDING CASES REPORT - 09/12/2024\n                                             MAVERICK - COUNTY CLERK - OLS COURT\n                              FILED PENDING CASES AS OF 09/12/2024 - SORTED BY FILE DATE - PAGE 1\n\nCAUSE #                  FILE DT  DEFENDANT'S NAME                      COURT   DOCKET DT  OUTSTANDING WARRANTS\n   ACTIVE ATTORNEY/S               1ST OFFENSE                            ST RPT COLUMN                                "

# %%
body
# Out:
# "30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
#Set up regex to remove all subsequent headers
#This regex should identify the headers even if the name of the district clerk changes later on
body = re.sub(r"""\n\x0c\s*[A-Z -]*\d{2}/\d{2}/\d{4}\n\s*\w{6,8}[A-Z0-9 -]*\n\s*[A-Z ]*\d{2}/\d{2}/\d{4}[A-Z0-9 -]*\n\n[A-Z ]*#\s*[A-Z -']*\n[A-Z0-9/ -]*\n\n""", '', body)
body
# Out:
# '30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
#Split the text on the '\n'
cases = body.split('\n')

# %%
#Establish a container list for the dictionaries
case_list = []
attorney_names = []
offense_list = []
st_rpt_list = []
temp_dict = {}

# %%
for line in cases:
    #Check if line is the start of a new case
    if not line[0].isspace():
        #Check if the temp_dict is empty.
        #If not, add temp_dict data to case_list
        if bool(temp_dict) == True:
            #Add list info to temp_dict
            temp_dict['Attorney'] = attorney_names
            temp_dict['First Offense'] = offense_list
            temp_dict['ST RPT Column'] = st_rpt_list
            
            #Add temp dict data to case_list
            case_list.append(temp_dict)
        
        #Reset temp_dict
        temp_dict = {}
        
        #Reset lists
        attorney_names = []
        offense_list = []
        st_rpt_list = []
        
        #Gather the cause number
        temp_dict['Cause Number'] = line[:22].strip()
        
        #Gather the file date
        temp_dict['File Date'] = line[22:34].strip()
        
        #Get defendant name
        temp_dict['Defendant'] = line[34:72].strip()
        
        #Get court
        temp_dict['Court'] = line[72:79].strip()
        
        #Get docket date
        temp_dict['Docket Date'] = line[79:89].strip()
        
        #Get outstanding warrants
        temp_dict['Outstanding Warrants'] = line[89:].strip()
        
        #End of line, so move to next one
    
    else:
        #Get attorney name
        attorney_name = line[:35].strip()
        
        #Check if attorney_name is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if attorney_name.isspace() == False and len(attorney_name) > 0:
            attorney_names.append(attorney_name.strip())
        
        #Get first offense
        offense = line[35:74].strip()
        
        #Check if offense is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if offense.isspace() == False and len(offense) > 0:
            offense_list.append(offense.strip())
        
        #Get ST RPT Column
        st_rpt = line[74:].strip()
        
        #Check if st_rpt is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if st_rpt.isspace() == False and len(st_rpt) > 0:
            st_rpt_list.append(st_rpt.strip())
        
        #End of line
        
#Check that the last case was added to the list
#If not, add it
#Add list info to temp_dict
temp_dict['Attorney'] = attorney_names
temp_dict['First Offense'] = offense_list
temp_dict['ST RPT Column'] = st_rpt_list

#Add temp dict data to case_list
case_list.append(temp_dict)

# %%
cases[0]
# Out:
# '30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    '

# %%
case_list
# Out:
# [{'Cause Number': '30778',
#   'File Date': '03/28/2022',
#   'Defendant': 'HERNANDEZ-GARCIA, EDUARDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['NEIGHBORHOOD DEFENDER SERVICES'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30868',
#   'File Date': '04/25/2022',
#   'Defendant': 'AGUILLEN-ARTEAGA, JOSE PEDRO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['WINFREY, JACKSON'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30902',
#   'File Date': '05/02/2022',
#   'Defendant': 'GONZALEZ-RAMIREZ, JOSUE',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['EHRENBERG, BRIAN'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30906',
#   'File Date': '05/05/2022',
#   'Defendant': 'MOLINA VALENCIA, JUAN ANTONIO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['TEXAS RIO GRANDE LEGAL AID,'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30931',
#   'File Date': '05/12/2022',
#   'Defendant': 'TORRES GALVAN, JOSE GUADALUPE',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30932',
#   'File Date': '05/12/2022',
#   'Defendant': 'DE LA CRUZ PALACIOS, FRANCISCO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30933',
#   'File Date': '05/12/2022',
#   'Defendant': 'ALCUDIA VENTURA, EUGENIO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30944',
#   'File Date': '05/12/2022',
#   'Defendant': 'TADEO GOMEZ, GUILLERMO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30945',
#   'File Date': '05/12/2022',
#   'Defendant': 'CAC POP, LUIS FERNANDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30946',
#   'File Date': '05/12/2022',
#   'Defendant': 'RIVERA NUNEZ, JOSE MEDARDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30947',
#   'File Date': '05/12/2022',
#   'Defendant': 'APARICIO, LUIS ALFREDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '30954',
#   'File Date': '05/12/2022',
#   'Defendant': 'CASTILLO RAMOS, JOSE FRANCISCO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['STARLING, KATHY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31007',
#   'File Date': '05/18/2022',
#   'Defendant': 'DE LA ROSA MATAMOROS, JOSE',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PALOMEQUE, PABLO'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31066',
#   'File Date': '06/22/2022',
#   'Defendant': 'GARCIA RIVERA, ALEXANDER',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['CAPELLO, MARY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31104',
#   'File Date': '07/15/2022',
#   'Defendant': 'NERI RODRIGUEZ, ELIAZAR',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['TEXAS RIO GRANDE LEGAL AID,'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31239',
#   'File Date': '08/04/2022',
#   'Defendant': 'DIAZ ESTRADA, CARLOS EDUARDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['NEIGHBORHOOD DEFENDER SERVICES'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31251',
#   'File Date': '08/04/2022',
#   'Defendant': 'VAZQUEZ CORDOVA, SAQUEO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['CAPELLO, MARY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31302',
#   'File Date': '08/15/2022',
#   'Defendant': 'VIDAL SANTACRUZ, ALVARO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31305',
#   'File Date': '08/15/2022',
#   'Defendant': 'GUEVARA CRUZ, CRISTIAN ALONSO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BERNOUDY, MICHAEL L'],
#   'First Offense': ['EVADING ARREST DETENTION'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31309',
#   'File Date': '08/15/2022',
#   'Defendant': 'VIDAL RENTERIA, JOSE',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31310',
#   'File Date': '08/15/2022',
#   'Defendant': 'HERNANDEZ GONZALEZ, JAIME',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31311',
#   'File Date': '08/15/2022',
#   'Defendant': 'HERNANDEZ AMAYA, WILSON RONALDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31312',
#   'File Date': '08/15/2022',
#   'Defendant': 'REYES ALVARDO, ADAN MICHEL',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['GLOVER, MALLORY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31314',
#   'File Date': '08/15/2022',
#   'Defendant': 'LOZANO AGUILAR, SAUL ANTONI',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['SANDERSON, JOANNE M'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31315',
#   'File Date': '08/15/2022',
#   'Defendant': 'HERNANDEZ ZACARIAS, JOSE RUFINO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31316',
#   'File Date': '08/15/2022',
#   'Defendant': 'LARA BELMONTES, JAYRO JESUS',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['ANDRADE, KIMBERLY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31328',
#   'File Date': '08/15/2022',
#   'Defendant': 'MANZANARES BARAHONA, JHON ANIBAL',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31329',
#   'File Date': '08/15/2022',
#   'Defendant': 'RAMIREZ RODRIGUEZ, MILTON ELIGIO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BEAUCHAMP, CODY'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31338',
#   'File Date': '08/18/2022',
#   'Defendant': 'HUERTA RODRIGUEZ, SERGIO LUIS',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BERNOUDY, MICHAEL L'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31339',
#   'File Date': '08/18/2022',
#   'Defendant': 'HUERTA RODRIGUEZ, MARIN',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BERNOUDY, MICHAEL L'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31341',
#   'File Date': '08/18/2022',
#   'Defendant': 'SANCHEZ HERNANDEZ, JOSE JUAN',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['BERNOUDY, MICHAEL L'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31343',
#   'File Date': '08/18/2022',
#   'Defendant': 'PINTO PEREZ, ELIEZER ISAIAS',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['NEIGHBORHOOD DEFENDER SERVICES'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31415',
#   'File Date': '09/20/2022',
#   'Defendant': 'ROCHA ZAMANO, JESUS',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31416',
#   'File Date': '09/20/2022',
#   'Defendant': 'ESCOTO CONTRERAS, OSWALDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31418',
#   'File Date': '09/20/2022',
#   'Defendant': 'AGUILAR ROCHA, LEOPOLDO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31419',
#   'File Date': '09/20/2022',
#   'Defendant': 'ALCANTARA RANGEL, MIGUEL ANGEL',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31424',
#   'File Date': '09/20/2022',
#   'Defendant': 'CHAVEZ OROZCO, PABLO',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']},
#  {'Cause Number': '31427',
#   'File Date': '09/20/2022',
#   'Defendant': 'RAZO CHAVEZ, MOISES',
#   'Court': 'OLS',
#   'Docket Date': '',
#   'Outstanding Warrants': '',
#   'Attorney': ['PERRODIN, JANET'],
#   'First Offense': ['CRIMINAL TRESPASS'],
#   'ST RPT Column': ['OTHER MISDEMEANOR']}]

# %%
#Create dataframe
df = pd.DataFrame(case_list)

# %%
df
# Out:
#    Cause Number   File Date                         Defendant Court  \
# 0         30778  03/28/2022         HERNANDEZ-GARCIA, EDUARDO   OLS
# 1         30868  04/25/2022      AGUILLEN-ARTEAGA, JOSE PEDRO   OLS
# 2         30902  05/02/2022           GONZALEZ-RAMIREZ, JOSUE   OLS
# 3         30906  05/05/2022     MOLINA VALENCIA, JUAN ANTONIO   OLS
# 4         30931  05/12/2022     TORRES GALVAN, JOSE GUADALUPE   OLS
# 5         30932  05/12/2022    DE LA CRUZ PALACIOS, FRANCISCO   OLS
# 6         30933  05/12/2022          ALCUDIA VENTURA, EUGENIO   OLS
# 7         30944  05/12/2022            TADEO GOMEZ, GUILLERMO   OLS
# 8         30945  05/12/2022            CAC POP, LUIS FERNANDO   OLS
# 9         30946  05/12/2022        RIVERA NUNEZ, JOSE MEDARDO   OLS
# 10        30947  05/12/2022            APARICIO, LUIS ALFREDO   OLS
# 11        30954  05/12/2022    CASTILLO RAMOS, JOSE FRANCISCO   OLS
# 12        31007  05/18/2022        DE LA ROSA MATAMOROS, JOSE   OLS
# 13        31066  06/22/2022          GARCIA RIVERA, ALEXANDER   OLS
# 14        31104  07/15/2022           NERI RODRIGUEZ, ELIAZAR   OLS
# 15        31239  08/04/2022      DIAZ ESTRADA, CARLOS EDUARDO   OLS
# 16        31251  08/04/2022           VAZQUEZ CORDOVA, SAQUEO   OLS
# 17        31302  08/15/2022           VIDAL SANTACRUZ, ALVARO   OLS
# 18        31305  08/15/2022     GUEVARA CRUZ, CRISTIAN ALONSO   OLS
# 19        31309  08/15/2022              VIDAL RENTERIA, JOSE   OLS
# 20        31310  08/15/2022         HERNANDEZ GONZALEZ, JAIME   OLS
# 21        31311  08/15/2022   HERNANDEZ AMAYA, WILSON RONALDO   OLS
# 22        31312  08/15/2022        REYES ALVARDO, ADAN MICHEL   OLS
# 23        31314  08/15/2022       LOZANO AGUILAR, SAUL ANTONI   OLS
# 24        31315  08/15/2022   HERNANDEZ ZACARIAS, JOSE RUFINO   OLS
# 25        31316  08/15/2022       LARA BELMONTES, JAYRO JESUS   OLS
# 26        31328  08/15/2022  MANZANARES BARAHONA, JHON ANIBAL   OLS
# 27        31329  08/15/2022  RAMIREZ RODRIGUEZ, MILTON ELIGIO   OLS
# 28        31338  08/18/2022     HUERTA RODRIGUEZ, SERGIO LUIS   OLS
# 29        31339  08/18/2022           HUERTA RODRIGUEZ, MARIN   OLS
# 30        31341  08/18/2022      SANCHEZ HERNANDEZ, JOSE JUAN   OLS
# 31        31343  08/18/2022       PINTO PEREZ, ELIEZER ISAIAS   OLS
# 32        31415  09/20/2022               ROCHA ZAMANO, JESUS   OLS
# 33        31416  09/20/2022         ESCOTO CONTRERAS, OSWALDO   OLS
# 34        31418  09/20/2022           AGUILAR ROCHA, LEOPOLDO   OLS
# 35        31419  09/20/2022    ALCANTARA RANGEL, MIGUEL ANGEL   OLS
# 36        31424  09/20/2022              CHAVEZ OROZCO, PABLO   OLS
# 37        31427  09/20/2022               RAZO CHAVEZ, MOISES   OLS
#
#    Docket Date Outstanding Warrants                          Attorney  \
# 0                                    [NEIGHBORHOOD DEFENDER SERVICES]
# 1                                                  [WINFREY, JACKSON]
# 2                                                  [EHRENBERG, BRIAN]
# 3                                       [TEXAS RIO GRANDE LEGAL AID,]
# 4                                                   [STARLING, KATHY]
# 5                                                   [STARLING, KATHY]
# 6                                                   [STARLING, KATHY]
# 7                                                   [STARLING, KATHY]
# 8                                                   [STARLING, KATHY]
# 9                                                   [STARLING, KATHY]
# 10                                                  [STARLING, KATHY]
# 11                                                  [STARLING, KATHY]
# 12                                                 [PALOMEQUE, PABLO]
# 13                                                    [CAPELLO, MARY]
# 14                                      [TEXAS RIO GRANDE LEGAL AID,]
# 15                                   [NEIGHBORHOOD DEFENDER SERVICES]
# 16                                                    [CAPELLO, MARY]
# 17                                                  [BEAUCHAMP, CODY]
# 18                                              [BERNOUDY, MICHAEL L]
# 19                                                  [BEAUCHAMP, CODY]
# 20                                                  [BEAUCHAMP, CODY]
# 21                                                  [BEAUCHAMP, CODY]
# 22                                                  [GLOVER, MALLORY]
# 23                                              [SANDERSON, JOANNE M]
# 24                                                  [BEAUCHAMP, CODY]
# 25                                                [ANDRADE, KIMBERLY]
# 26                                                  [BEAUCHAMP, CODY]
# 27                                                  [BEAUCHAMP, CODY]
# 28                                              [BERNOUDY, MICHAEL L]
# 29                                              [BERNOUDY, MICHAEL L]
# 30                                              [BERNOUDY, MICHAEL L]
# 31                                   [NEIGHBORHOOD DEFENDER SERVICES]
# 32                                                  [PERRODIN, JANET]
# 33                                                  [PERRODIN, JANET]
# 34                                                  [PERRODIN, JANET]
# 35                                                  [PERRODIN, JANET]
# 36                                                  [PERRODIN, JANET]
# 37                                                  [PERRODIN, JANET]
#
#                  First Offense        ST RPT Column
# 0          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 2          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 3          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 4          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 5          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 6          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 7          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 8          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 9          [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 10         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 11         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 12         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 13         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 14         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 15         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 16         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 17         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 18  [EVADING ARREST DETENTION]  [OTHER MISDEMEANOR]
# 19         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 20         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 21         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 22         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 23         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 24         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 25         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 26         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 27         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 28         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 29         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 30         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 31         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 32         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 33         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 34         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 35         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 36         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 37         [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]

# %% [markdown]
# __Remove MTR Case Counts__
#
# The bottom of the report has a count of all cases and includes more info on MTR-A cases.
#
# We don't need it, so use regex to remove it.

# %%
#Read in the whole document

#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page_num, page in enumerate(PDFPage.get_pages(fh, caching=True, check_extractable=True)):
        #Process the current page
        page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

#print(text)

# %%
#Remove the header
header = text[:500]
body = text[500:]

# %%
header
# Out:
# "                                     CRIMINAL DETAILED PENDING CASES REPORT - 09/12/2024\n                                             MAVERICK - COUNTY CLERK - OLS COURT\n                              FILED PENDING CASES AS OF 09/12/2024 - SORTED BY FILE DATE - PAGE 1\n\nCAUSE #                  FILE DT  DEFENDANT'S NAME                      COURT   DOCKET DT  OUTSTANDING WARRANTS\n   ACTIVE ATTORNEY/S               1ST OFFENSE                            ST RPT COLUMN                                "

# %%
#Remove subsequent headers using regex
body = re.sub(r"""\n\x0c\s*[A-Z -]*\d{2}/\d{2}/\d{4}\n\s*\w{6,8}[A-Z0-9 -]*\n\s*[A-Z ]*\d{2}/\d{2}/\d{4}[A-Z0-9 -]*\n\n[A-Z ]*#\s*[A-Z -']*\n[A-Z0-9/ -]*\n\n""", '', body)
body
# Out:
# "       \n\n30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY    ...

# %%
#Remove leading and trailing whitespaces from the body text
body = body.strip()

# %%
#Now try removing the last section based on the number of characters
new_body = re.sub(r"""\nTOTAL NUMBER OF CASES FILED: [0-9\n-]*MTR-A[A-Z\n ]*[-]*""", '', body)
new_body
# Out:
# "30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
new_body = re.sub(r"""\nTOTAL NUMBER OF MTR-A FILINGS: [0-9\n-]*ALL OTHER CASES ADDED/APPEALED[\n-]*""", '', new_body)
new_body
# Out:
# "30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
new_body = re.sub(r"""\nTOTAL NUMBER OF CASES ADDED/APPEALED: [0-9]*""", '', new_body)
new_body
# Out:
# "30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
new_body = re.sub(r"""\nTHE FOLLOWING IS A LIST OF ERRORS FOUND:\n [0-9A-Z\n\-#=;'\., ]*""", '', new_body)
new_body
# Out:
# "30778                 03/28/2022  HERNANDEZ-GARCIA, EDUARDO             OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30868                 04/25/2022  AGUILLEN-ARTEAGA, JOSE PEDRO          OLS                                    \n   WINFREY, JACKSON                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30902                 05/02/2022  GONZALEZ-RAMIREZ, JOSUE               OLS                                    \n   EHRENBERG, BRIAN                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30906                 05/05/2022  MOLINA VALENCIA, JUAN ANTONIO         OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30931                 05/12/2022  TORRES GALVAN, JOSE GUADALUPE         OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30932                 05/12/2022  DE LA CRUZ PALACIOS, FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30933                 05/12/2022  ALCUDIA VENTURA, EUGENIO              OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30944                 05/12/2022  TADEO GOMEZ, GUILLERMO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30945                 05/12/2022  CAC POP, LUIS FERNANDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30946                 05/12/2022  RIVERA NUNEZ, JOSE MEDARDO            OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30947                 05/12/2022  APARICIO, LUIS ALFREDO                OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n30954                 05/12/2022  CASTILLO RAMOS, JOSE FRANCISCO        OLS                                    \n   STARLING, KATHY                 CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31007                 05/18/2022  DE LA ROSA MATAMOROS, JOSE            OLS                                    \n   PALOMEQUE, PABLO                CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31066                 06/22/2022  GARCIA RIVERA, ALEXANDER              OLS                                    \n   CAPELLO, MARY                   CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31104                 07/15/2022  NERI RODRIGUEZ, ELIAZAR               OLS                                    \n   TEXAS RIO GRANDE LEGAL AID,     CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31239                 08/04/2022  DIAZ ESTRADA, CARLOS EDUARDO          OLS                                    \n   NEIGHBORHOOD DEFENDER SERVICES  CRIMINAL TRESPASS                      OTHER MISDEMEANOR                                   \n31251                 08/04/2022  VAZQUEZ CORDOVA, SAQUEO               OLS                                    \n   CAPELLO, MARY               ...

# %%
#Split the text on the '\n'
cases = new_body.split('\n')

# %%
#Establish a container list for the dictionaries
case_list = []
attorney_names = []
offense_list = []
st_rpt_list = []
temp_dict = {}

# %%
len(cases[0])
# Out:
# 111

# %%
#Remove cases that happen to be empty or consist of whitespace only
cases = [case for case in cases if case.isspace() == False and len(case) > 0]

# %%
for line in cases:
    #Check if line is the start of a new case
    if not line[0].isspace():
        #Check if the temp_dict is empty.
        #If not, add temp_dict data to case_list
        if bool(temp_dict) == True:
            #Add list info to temp_dict
            temp_dict['Attorney'] = attorney_names
            temp_dict['First Offense'] = offense_list
            temp_dict['ST RPT Column'] = st_rpt_list
            
            #Add temp dict data to case_list
            case_list.append(temp_dict)
        
        #Reset temp_dict
        temp_dict = {}
        
        #Reset lists
        attorney_names = []
        offense_list = []
        st_rpt_list = []
        
        #Gather the cause number
        temp_dict['Cause Number'] = line[:22].strip()
        
        #Gather the file date
        temp_dict['File Date'] = line[22:34].strip()
        
        #Get defendant name
        temp_dict['Defendant'] = line[34:72].strip()
        
        #Get court
        temp_dict['Court'] = line[72:79].strip()
        
        #Get docket date
        temp_dict['Docket Date'] = line[79:89].strip()
        
        #Get outstanding warrants
        temp_dict['Outstanding Warrants'] = line[89:].strip()
        
        #End of line, so move to next one
    
    else:
        #Get attorney name
        attorney_name = line[:35].strip()
        
        #Check if attorney_name is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if attorney_name.isspace() == False and len(attorney_name) > 0:
            attorney_names.append(attorney_name.strip())
        
        #Get first offense
        offense = line[35:74].strip()
        
        #Check if offense is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if offense.isspace() == False and len(offense) > 0:
            offense_list.append(offense.strip())
        
        #Get ST RPT Column
        st_rpt = line[74:].strip()
        
        #Check if st_rpt is all whitesapace. If not, strip it and add to names list
        #Also check that the string is not empty
        if st_rpt.isspace() == False and len(st_rpt) > 0:
            st_rpt_list.append(st_rpt.strip())
        
        #End of line
        
#Check that the last case was added to the list
#If not, add it
#Add list info to temp_dict
temp_dict['Attorney'] = attorney_names
temp_dict['First Offense'] = offense_list
temp_dict['ST RPT Column'] = st_rpt_list

#Add temp dict data to case_list
case_list.append(temp_dict)

# %%
#Create dataframe
df = pd.DataFrame(case_list)
df
# Out:
#      Cause Number   File Date                        Defendant Court  \
# 0           30778  03/28/2022        HERNANDEZ-GARCIA, EDUARDO   OLS
# 1           30868  04/25/2022     AGUILLEN-ARTEAGA, JOSE PEDRO   OLS
# 2           30902  05/02/2022          GONZALEZ-RAMIREZ, JOSUE   OLS
# 3           30906  05/05/2022    MOLINA VALENCIA, JUAN ANTONIO   OLS
# 4           30931  05/12/2022    TORRES GALVAN, JOSE GUADALUPE   OLS
# ...           ...         ...                              ...   ...
# 1306        36671  09/11/2024  BENITEZ AGUILAR, JOSE ALEJANDRO   OLS
# 1307        36672  09/11/2024           MONTERROS, RANDY ARIEL   OLS
# 1308        36673  09/11/2024                    PAIVA, RAFAEL   OLS
# 1309        36674  09/11/2024             DE SANTANA, GEMERSON   OLS
# 1310        36675  09/11/2024            RODRIGUES BRAZ, TIAGO   OLS
#
#      Docket Date Outstanding Warrants                          Attorney  \
# 0                                      [NEIGHBORHOOD DEFENDER SERVICES]
# 1                                                    [WINFREY, JACKSON]
# 2                                                    [EHRENBERG, BRIAN]
# 3                                         [TEXAS RIO GRANDE LEGAL AID,]
# 4                                                     [STARLING, KATHY]
# ...          ...                  ...                               ...
# 1306                                                  [BUTTS, SONYA J.]
# 1307                                               [CARABALLO, BARBARA]
# 1308                                                 [CHAVEZ, JONATHAN]
# 1309                                                 [CHAVEZ, JONATHAN]
# 1310                                                 [CHAVEZ, JONATHAN]
#
#             First Offense        ST RPT Column
# 0     [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1     [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 2     [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 3     [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 4     [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# ...                   ...                  ...
# 1306  [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1307  [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1308  [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1309  [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
# 1310  [CRIMINAL TRESPASS]  [OTHER MISDEMEANOR]
#
# [1311 rows x 9 columns]

# %% [markdown]
# # Build Function
#
# Create a function to gather the info from the entire document.

# %%
def extract_criminal_ols_pdf_data(text):
    """
    This function takes in the entire PDF document as a string of text. It will gather the info for each case
    and add the info to a dictionary. The dictionary for each case will be added to a list which will be turned into
    a dataframe.
    
    Parameter:
        -text: A string consisting of the text of the entire PDF document.
        
    Returns:
        -df: A dataframe of the newly gathered case info
    """
    
    #Initialize containers
    case_list = []
    attorney_names = []
    offense_list = []
    st_rpt_list = []
    temp_dict = {}
    
    #Separate the first header from the body
    #We'll use this to identify the county later
    header = text[:500]
    
    #Body
    body = text[500:]
    
    #Remove leading and trailing whitespaces from the body text
    body = body.strip()
    
    #Use if statement to check for county names inside the header info
    if header.count('MAVERICK') >= 1:
        county = 'Maverick'
    elif header.count('DIMMIT') >= 1:
        county = 'Dimmit'
    elif header.count('ZAVALA') >= 1:
        county = 'Zavala'
    else:
        county = 'Something went wrong!'
        
    #Set up regex to remove all subsequent headers
    #This regex should identify the headers even if the name of the district clerk changes later on
    body = re.sub(r"""\n\x0c\s*[A-Z -]*\d{2}/\d{2}/\d{4}\n\s*\w{6,8}[A-Z0-9 -]*\n\s*[A-Z ]*\d{2}/\d{2}/\d{4}[A-Z0-9 -]*\n\n[A-Z ]*#\s*[A-Z -']*\n[A-Z0-9/ -]*\n\n""", '', body)
    
    #########################################################################################################
    #Now remove the last divider sections using regex
    body = re.sub(r"""\nTOTAL NUMBER OF CASES FILED: [0-9\n-]*MTR-A[A-Z\n ]*[-]*""", '', body)
    
    body = re.sub(r"""\nTOTAL NUMBER OF MTR-A FILINGS: [0-9\n-]*ALL OTHER CASES ADDED/APPEALED[\n-]*""", '', body)
    
    body = re.sub(r"""\nTOTAL NUMBER OF CASES ADDED/APPEALED: [0-9- a-zA-Z\.#;,:'=\n]*""", '', body)
    
    body = re.sub(r"""\nTHE FOLLOWING IS A LIST OF ERRORS FOUND:\n [0-9A-Z\n\-#=;'\., ]*""", '', body)
    
    #########################################################################################################
    
    #Split the text on the '\n' to isolate each case
    cases = body.split('\n')
    
    #Remove cases that happen to be empty or consist of whitespace only
    cases = [case for case in cases if case.isspace() == False and len(case) > 0]
    
    #Loop through each line. Add case info to temp dict, and then add that to the case list
    for line in cases:
        #Check if line is the start of a new case
        if not line[0].isspace():
            #Check if the temp_dict is empty.
            #If not, add temp_dict data to case_list
            if bool(temp_dict) == True:
                #Add list info to temp_dict
                temp_dict['Attorney'] = attorney_names
                temp_dict['First Offense'] = offense_list
                temp_dict['ST RPT Column'] = st_rpt_list

                #Add temp dict data to case_list
                case_list.append(temp_dict)

            #Reset temp_dict
            temp_dict = {}

            #Reset lists
            attorney_names = []
            offense_list = []
            st_rpt_list = []
            
            #Assign county
            temp_dict['County'] = county

            #Gather the cause number
            temp_dict['Cause Number'] = line[:22].strip()
            
            #Assign case type
            temp_dict['Case Type'] = 'Criminal'
            
            #Assign status
            temp_dict['Status'] = 'Open'

            #Gather the file date
            temp_dict['File Date'] = line[22:34].strip()

            #As of 13 June 2023, we are no longer collecting names
            #Get defendant name
            temp_dict['Defendant'] = line[34:72].strip()
        
            #Get court
            temp_dict['Court'] = line[72:79].strip()

            #Get docket date
            temp_dict['Docket Date'] = line[79:89].strip()

            #Get outstanding warrants
            temp_dict['Outstanding Warrants'] = line[89:].strip()

            #End of line, so move to next one

        else:
            #As of 13 June 2023, we are no longer collecting names
            
            #Get attorney name
            attorney_name = line[:35].strip()

            #Check if attorney_name is all whitesapace. If not, strip it and add to names list
            #Also check that the string is not empty
            if attorney_name.isspace() == False and len(attorney_name) > 0:
                attorney_names.append(attorney_name.strip())

            #Get first offense
            offense = line[35:74].strip()

            #Check if offense is all whitesapace. If not, strip it and add to names list
            #Also check that the string is not empty
            if offense.isspace() == False and len(offense) > 0:
                offense_list.append(offense.strip())

            #Get ST RPT Column
            st_rpt = line[74:].strip()

            #Check if st_rpt is all whitesapace. If not, strip it and add to names list
            #Also check that the string is not empty
            if st_rpt.isspace() == False and len(st_rpt) > 0:
                st_rpt_list.append(st_rpt.strip())

            #End of line
        
    #Check that the last case was added to the list
    #If not, add it
    #Add list info to temp_dict
    temp_dict['Attorney'] = attorney_names
    temp_dict['First Offense'] = offense_list
    temp_dict['ST RPT Column'] = st_rpt_list

    #Add temp dict data to case_list
    case_list.append(temp_dict)

    
    #How many?
    print(f'Collected Data From {len(case_list)} Cases.')
    
    #Create dataframe
    df = pd.DataFrame(case_list)
    
    return df

# %% [markdown]
# # Test Function

# %%
#Set up the pdf path
pdf_path = '/Users/johnathonsmith/Downloads/MAV_OLS_Pending.pdf'

# %%
#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page_num, page in enumerate(PDFPage.get_pages(fh, caching=True, check_extractable=True)):
        #Process the current page
        page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

#print(text)

# %%
df = extract_criminal_ols_pdf_data(text)
# Out:
# Collected Data From 1311 Cases.

# %%
df
# Out:
#         County Cause Number Case Type Status   File Date  \
# 0     Maverick        30778  Criminal   Open  03/28/2022
# 1     Maverick        30868  Criminal   Open  04/25/2022
# 2     Maverick        30902  Criminal   Open  05/02/2022
# 3     Maverick        30906  Criminal   Open  05/05/2022
# 4     Maverick        30931  Criminal   Open  05/12/2022
# ...        ...          ...       ...    ...         ...
# 1306  Maverick        36671  Criminal   Open  09/11/2024
# 1307  Maverick        36672  Criminal   Open  09/11/2024
# 1308  Maverick        36673  Criminal   Open  09/11/2024
# 1309  Maverick        36674  Criminal   Open  09/11/2024
# 1310  Maverick        36675  Criminal   Open  09/11/2024
#
#                             Defendant Court Docket Date Outstanding Warrants  \
# 0           HERNANDEZ-GARCIA, EDUARDO   OLS
# 1        AGUILLEN-ARTEAGA, JOSE PEDRO   OLS
# 2             GONZALEZ-RAMIREZ, JOSUE   OLS
# 3       MOLINA VALENCIA, JUAN ANTONIO   OLS
# 4       TORRES GALVAN, JOSE GUADALUPE   OLS
# ...                               ...   ...         ...                  ...
# 1306  BENITEZ AGUILAR, JOSE ALEJANDRO   OLS
# 1307           MONTERROS, RANDY ARIEL   OLS
# 1308                    PAIVA, RAFAEL   OLS
# 1309             DE SANTANA, GEMERSON   OLS
# 1310            RODRIGUES BRAZ, TIAGO   OLS
#
#                               Attorney        First Offense  \
# 0     [NEIGHBORHOOD DEFENDER SERVICES]  [CRIMINAL TRESPASS]
# 1                   [WINFREY, JACKSON]  [CRIMINAL TRESPASS]
# 2                   [EHRENBERG, BRIAN]  [CRIMINAL TRESPASS]
# 3        [TEXAS RIO GRANDE LEGAL AID,]  [CRIMINAL TRESPASS]
# 4                    [STARLING, KATHY]  [CRIMINAL TRESPASS]
# ...                                ...                  ...
# 1306                 [BUTTS, SONYA J.]  [CRIMINAL TRESPASS]
# 1307              [CARABALLO, BARBARA]  [CRIMINAL TRESPASS]
# 1308                [CHAVEZ, JONATHAN]  [CRIMINAL TRESPASS]
# 1309                [CHAVEZ, JONATHAN]  [CRIMINAL TRESPASS]
# 1310                [CHAVEZ, JONATHAN]  [CRIMINAL TRESPASS]
#
#             ST RPT Column
# 0     [OTHER MISDEMEANOR]
# 1     [OTHER MISDEMEANOR]
# 2     [OTHER MISDEMEANOR]
# 3     [OTHER MISDEMEANOR]
# 4     [OTHER MISDEMEANOR]
# ...                   ...
# 1306  [OTHER MISDEMEANOR]
# 1307  [OTHER MISDEMEANOR]
# 1308  [OTHER MISDEMEANOR]
# 1309  [OTHER MISDEMEANOR]
# 1310  [OTHER MISDEMEANOR]
#
# [1311 rows x 12 columns]

# %% [markdown]
# __Convert Lists To Strings__

# %%
def convert_name_list_to_string(name_list):
    """
    This function takes in the list of names for the Plaintiff, Plaintiff Attorney, Defendant, and Defendant Attorney
    in the civil cases dataframe. It will join the names in each list with a new line character. This is necessary to
    upload the dataframe to a google sheet.

    Parameter:
        - name_list: The list of names

    Returns:
        - string: A single string consisting of all the names in the list joined by new lines.
    """

    name_string = '\n'.join(name_list)
    
    return name_string

# %%
df['First Offense'] = df['First Offense'].map(convert_name_list_to_string)
df['ST RPT Column'] = df['ST RPT Column'].map(convert_name_list_to_string)
df['Attorney'] = df['Attorney'].map(convert_name_list_to_string)

# %%
df[df['Cause Number'] == '36649']
# Out:
#         County Cause Number Case Type Status   File Date  \
# 1284  Maverick        36649  Criminal   Open  08/30/2024
#
#                  Defendant Court Docket Date Outstanding Warrants  \
# 1284  MOHENO SANCHEZ, YANS   OLS
#
#             Attorney                                First Offense  \
# 1284  MARES, ALFREDO  CRIM TRESPASS\nHABIT/SHLTR/SUPRFUND/INFSTRT
#
#           ST RPT Column
# 1284  OTHER MISDEMEANOR

# %% [markdown]
# # Send Data To Google Sheets

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
#Set up credentials
gc = gspread.service_account(filename='credentials.json')

# %%
#Open Google Sheet By Name
gsheet = gc.open("Pending Reports")

# %%
#OLS cases go to the 'OLS Cases' tab
ols_sheet = gsheet.worksheet('OLS Cases')

# %%
#Clear what's currently on the sheet
ols_sheet.clear()
# Out:
# {'spreadsheetId': '1b3fmZrbfwZWMvu4kUGJSSGsp61utlE0Ny-ebozZ5aBk',
#  'clearedRange': "'OLS Cases'!A1:Z2312"}

# %%
ols_sheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1b3fmZrbfwZWMvu4kUGJSSGsp61utlE0Ny-ebozZ5aBk',
#  'updatedRange': "'OLS Cases'!A1:L1312",
#  'updatedRows': 1312,
#  'updatedColumns': 12,
#  'updatedCells': 15744}
