# %%
import numpy as np
import pandas as pd
import re
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io

# %%
#Set up the pdf path
pdf_path = '/Users/johnathonsmith/Downloads/24_01_22_DJU MJU ZJU _ All Counties.pdf'

# %%
#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page_num, page in enumerate(PDFPage.get_pages(fh, caching=True, check_extractable=True)):
        #Process the current page
        page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

#print(text)

# %%
text
# Out:
# '                         COURT COORDINATOR - JUVENILE CASE FILINGS\n              FILE DATES: ON OR AFTER 01/22/2024 - COURT: 293RD DISTRICT COURT\n            FILING COUNTY: ALL COUNTIES - FILING OFFICE: DISTRICT CLERK - PAGE 1\n\nKEY              CAUSE #   FILE DATE  COURT                           RESPONDENT                              \n     OFFENSE(S)                                                                        DOCKET DATE  DISPO. DATE\n\n487      08-03-00134-DJU  03/20/2008  293RD DISTRICT COURT            HERNANDEZ, GABRIEL LEDESMA               \n     AGG ASSAULT W/DEADLY WEAPON                                                                               \n512      08-10-00208-ZJU  10/21/2008  293RD DISTRICT COURT            MATA JR, MAURICIO JIMENEZ                \n     BURGLARY OF HABITATION                                                                                    \n513      09-03-00212-ZJU  03/09/2009  293RD DISTRICT COURT            BALBOA, III, PABLO                       \n     CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE                                                 06/10/2009\n488      09-07-00146-DJU  07/30/2009  293RD DISTRICT COURT            RUBIO, FERMIN                            \n     BURGLARY OF BUILDING                                                                                      \n514      09-08-00214-ZJU  08/20/2009  293RD DISTRICT COURT            GONZALEZ, JUAN CARLOS                    \n     BURGLARY OF HABITATION                                                                          10/05/2009\n515      09-08-00216-ZJU  08/20/2009  293RD DISTRICT COURT            SAMBRANO, ROLANDO                        \n     BURGLARY OF HABITATION                                                                          10/05/2009\n489      10-01-00148-DJU  01/11/2010  293RD DISTRICT COURT            HERRERA, JOSE GUARNERO                   \n     MURDER                                                                                          03/16/2010\n516      10-04-00218-ZJU  04/14/2010  293RD DISTRICT COURT            CORONADO, JR., FRANCISCO                 \n     CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER                                                             \n     CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER                                                             \n     CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER                                                             \n517      10-04-00220-ZJU  04/29/2010  293RD DISTRICT COURT            ALONZO, JUAN JAVIER                      \n     AGG ASSAULT CAUSES SERIOUS BODILY INJ                                                           08/12/2010\n518      11-02-00222-ZJU
#  '519      11-10-00224-ZJU  10/18/2011  293RD DISTRICT COURT            PESINA, RAMIRO JR                        ',
#  '     TERRORISTIC THREAT                                                                              12/06/2011',
#  '     ASSAULT CAUSES BODILY INJ                                                                                 ',
#  '     POSS MARIJ <2OZ                                                                                           ',
#  '     CHILD LABOR LAW                                                                                           ',
#  '     CHILD LABOR LAW                                                                                           ',
#  '     CHILD LABOR LAW                                                                                           ',
#  '520      11-10-00226-ZJU  10/26/2011  293RD DISTRICT COURT            PESINA, DORA                             ',
#  '     BURGLARY OF HABITATION                                                                          12/06/2011',
#  '     BURGLARY OF HABITATION                                                                                    ',
#  '521      11-10-00228-ZJU  10/26/2011  293RD DISTRICT COURT            CAMPUZANO, JESUS ALBERTO                 ',
#  '     BURGLARY OF HABITATION                                                                          12/05/2011',
#  '     BURGLARY OF HABITATION                                                                                    ',
#  '     BURGLARY OF HABITATION                                                                                    ',
#  '     BURGLARY OF HABITATION                                                                                    ',
#  '491      11-12-00152-DJU  12/12/2011  293RD DISTRICT COURT            BALDERAS, HUGO JACINTO                   ',
#  '     BURGLARY OF VEHICLE                                                                             06/07/2013',
#  '492      12-02-00154-DJU  02/22/2012  293RD DISTRICT COURT            RIOS, RICARDO FERNANDO                   ',
#  '     POSS MARIJUANA <= 2 OZ                                                                          04/03/2012',
#  '522      12-03-00230-ZJU  03/16/2012  293RD DISTRICT COURT            GONZALEZ, JUAN CARLOS                    ',
#  '     BURGLARY OF BUILDING                                                                            04/02/2012',
#  '523      12-03-00232-ZJU  03/16/2012  293RD DISTRICT COURT            MORALES, JR, SERGIO                      ',
#  '     BURGLARY OF BUILDING                                                                            05/01/2012',
#  '524      12-04-00234-ZJU  04/02/2012  293RD DISTRICT COURT            BALBOA, JIMMY                            ',
#  '     BURGLARY OF BUILDING                                                                            05/01/2012',
#  '493      12-05-00156-DJU  05/02/2012  293RD DISTRICT COURT            OCHOA, GIOVANNI ALLAN                    ',
#  '     BURGLARY OF VEHICLE                                                                             07/16/2013',
#  '494      12-05-00158-DJU  05/25/2012  293RD DISTRICT COURT            GARCIA, JASMINE NICOLE                   ',
#  '     THEFT PROP>=$50<$500                                                                            09/20/2013',
#  '495      12-06-00160-DJU  06/25/2012  293RD DISTRICT COURT            DELEON, III, RENE                        ',
#  '     BURGLARY OF HABITATION                                                                          11/02/2012',
#  '525      12-06-00236-ZJU  06/26/2012  293RD DISTRICT COURT            PUENTE, EMILIO III                       ',
#  '     EVADING ARREST DETENTION                                                                        09/04/2012',
#  '496      12-08-00162-DJU  08/16/2012  293RD DISTRICT COURT            RODRIGUEZ, JR., ALFREDO AUGUSTINE        ',
#  '     ASSLT CAUSES BODILY INJ                                                                         05/30/2013',
#  '526      12-10-00238-ZJU  10/31/2012  293RD DISTRICT COURT            CISNEROS, STEVEN LEE                     ',
#  '     CRIMINAL MISCHIEF >=$50<$500                                                                    01/02/2013',
#  '497      12-12-00164-DJU  12/17/2012  293RD DISTRICT COURT            LUMBRERAS, JR., ADRIAN                   ',
#  '',
#  '',
#  '     ASSLT CAUSES BODILY INJ                                                                         03/08/2013',
#  '405      22-09-JUANH-MJU  09/06/2022  293RD DISTRICT COURT            JUAN HUGO ALDACO                         ',
#  '417      22-10-00582-MJU  10/14/2022  293RD DISTRICT COURT            CARLOS MANUEL RODRIGUEZ                  ',
#  '     AGG ROBBERY                                                                                               ',
#  '410      22-11-JUANP-MJU  11/04/2022  293RD DISTRICT COURT            JUAN PABLO RODRIGUEZ                     ',
#  '414      22-11-ALEXA-MJU  11/16/2022  293RD DISTRICT COURT            ALEXANDER VILLEGAS                       ',
#  '418      22-11-00584-MJU  11/16/2022  293RD DISTRICT COURT            DAVID J. ZAPATA CASTILLEJA               ',
#  '     EVADING ARREST DETENTION                                                                                  ',
#  '     CRIMINAL MISCHIEF >=$100<$750                                                                             ',
#  '     EVADING ARREST DET W/VEH                                                                                  ',
#  '419       22-12-0216-DJU  12/15/2022  293RD DISTRICT COURT            ROLANDO RJ REYES III                     ',
#  '     UNL CARRYING WEAPON                                                                                       ',
#  '420       22-12-0218-DJU  12/22/2022  293RD DISTRICT COURT            MARTELL WILLIAMS                         ',
#  '     UNL CARRYING WEAPON                                                                                       ',
#  '423       23-03-0220-DJU  03/06/2023  293RD DISTRICT COURT            EBERT JARED LANDERO                      ',
#  '     EVADING ARREST/DET USING VEH                                                                              ',
#  '436      23-02-00586-MJU  03/06/2023  293RD DISTRICT COURT            JONATHAN BALLONES                        ',
#  '     POSS CS PG 1 >=1G<4G                                                                                      ',
#  '435      23-03-00588-MJU  03/27/2023  293RD DISTRICT COURT            ADRIAN ALEXANDER MCGUIRE, JR             ',
#  '     ASSAULT CAUSES BODILY INJ                                                                                 ',
#  '     EVADING ARREST DETENTION                                                                                  ',
#  '439       23-05-0222-DJU  05/04/2023  293RD DISTRICT COURT            IAN THOMAS GEST                          ',
#  '     UNAUTH USE OF VEHICLE                                                                                     ',
#  '442      23-05-00590-MJU  05/08/2023  293RD DISTRICT COURT            NATHANIEL SETH PEREZ                     ',
#  '     ASSAULT PEACE OFFICER/JUDGE                                                        06/03/2024             ',
#  '     EVADING ARREST DET W/VEH                                                                                  ',
#  '451       23-07-0224-DJU  07/26/2023  293RD DISTRICT COURT            JULIAN GABRIEL MAGALLAN                  ',
#  '     SMUGGLING OF PERSONS: FIREARM                                                                             ',
#  '452      23-07-00592-MJU  07/29/2023  293RD DISTRICT COURT            ASHLEY BERNABE LEYVA                     ',
#  '     EVADING ARREST DET W/VEH                                                           04/04/2024             ',
#  '537       23-10-0226-DJU  10/19/2023  293RD DISTRICT COURT            FRANCISCO MIGUEL GARZA                   ',
#  '     AGG ASSAULT CAUSES SERIOUS BODILY INJ                                                                     ',
#  '',
#  'TOTAL JUVENILE CASES LISTED: 117']

# %% [markdown]
# # Drop the Last Case
#
# It's just the total case count

# %%
cases[-1]
# Out:
# 'TOTAL JUVENILE CASES LISTED: 117'

# %%
cases.pop()
cases[-1]
# Out:
# ''

# %% [markdown]
# # Find the Data

# %%
#Only work with the first case for now
case = cases[0]
case
# Out:
# '487      08-03-00134-DJU  03/20/2008  293RD DISTRICT COURT            HERNANDEZ, GABRIEL LEDESMA               '

# %% [markdown]
# __Key__

# %%
key = case[:9].strip()
key
# Out:
# '487'

# %% [markdown]
# __Cause Number__

# %%
cause_number = case[9:26].strip()
cause_number
# Out:
# '08-03-00134-DJU'

# %% [markdown]
# __File Date__

# %%
file_date = case[26:38].strip()
file_date
# Out:
# '03/20/2008'

# %% [markdown]
# __Court__

# %%
court = case[38:70].strip()
court
# Out:
# '293RD DISTRICT COURT'

# %% [markdown]
# __Respondent__

# %%
respondent = case[70:].strip()
respondent
# Out:
# 'HERNANDEZ, GABRIEL LEDESMA'

# %%
#Find the data on the next line (Offense, Docket Date, Disposition Date)
case = cases[5]
case
# Out:
# '     CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE                                                 06/10/2009'

# %% [markdown]
# __Offense__

# %%
offense = case[5:88].strip()
offense
# Out:
# 'CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE'

# %% [markdown]
# __Docket Date__

# %%
docket_date = case[88:98].strip()
docket_date
# Out:
# ''

# %% [markdown]
# __Disposition Date__

# %%
dispo_date = case[98:].strip()
dispo_date
# Out:
# '06/10/2009'

# %% [markdown]
# # Build a Dataframe

# %%
#Establish a container list for the dictionaries
case_list = []
offense_list = []
docket_date_list = []
dispo_date_list = []
temp_dict = {}

# %%
for line in cases:
    if line.isspace() or len(line) == 0:
        continue
    
    #Check if line is the start of a new case
    if not line[0].isspace():
        #Check if the temp_dict is empty.
        #If not, add temp_dict data to case_list
        if bool(temp_dict) == True:
            #Add list info to temp_dict
            temp_dict['Offense'] = offense_list
            temp_dict['Docket Date'] = docket_date_list
            temp_dict['Disposition Date'] = dispo_date_list
            
            #Add temp dict data to case_list
            case_list.append(temp_dict)
        
        #Reset temp_dict
        temp_dict = {}
        
        #Reset lists
        offense_list = []
        docket_date_list = []
        dispo_date_list = []
        
        #Gather the cause number
        temp_dict['Cause Number'] = line[9:26].strip()
        
        #Gather the file date
        temp_dict['File Date'] = line[26:38].strip()
        
        #Get court
        #temp_dict['Court'] = line[38:70].strip()
        
        #Get respondent
        #temp_dict['Respondent'] = line[70:].strip()
        
        #End of line, so move to next one
    
    else:
        #Get offenses
        offense = line[5:88].strip()
        
        #Check if offense is all whitesapace. If not, strip it and add to list
        #Also check that the string is not empty
        if offense.isspace() == False and len(offense) > 0:
            offense_list.append(offense.strip())
            
        #Get Docket Date
        docket_date = line[88:98].strip()
        
        #Check if offense is all whitesapace. If not, strip it and add to list
        #Also check that the string is not empty
        if docket_date.isspace() == False and len(docket_date) > 0:
            docket_date_list.append(docket_date.strip())
            
        #Get Disposition Date
        dispo_date = line[98:].strip()
        
        #Check if offense is all whitesapace. If not, strip it and add to list
        #Also check that the string is not empty
        if dispo_date.isspace() == False and len(dispo_date) > 0:
            dispo_date_list.append(dispo_date.strip())
        
        #End of line
        
#Check that the last case was added to the list
#If not, add it
#Add list info to temp_dict
temp_dict['Offense'] = offense_list
temp_dict['Docket Date'] = docket_date_list
temp_dict['Disposition Date'] = dispo_date_list

#Add temp dict data to case_list
case_list.append(temp_dict)

# %%
len(case_list)
# Out:
# 117

# %%
case_list
# Out:
# [{'Cause Number': '08-03-00134-DJU',
#   'File Date': '03/20/2008',
#   'Offense': ['AGG ASSAULT W/DEADLY WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '08-10-00208-ZJU',
#   'File Date': '10/21/2008',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '09-03-00212-ZJU',
#   'File Date': '03/09/2009',
#   'Offense': ['CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE'],
#   'Docket Date': [],
#   'Disposition Date': ['06/10/2009']},
#  {'Cause Number': '09-07-00146-DJU',
#   'File Date': '07/30/2009',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '09-08-00214-ZJU',
#   'File Date': '08/20/2009',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['10/05/2009']},
#  {'Cause Number': '09-08-00216-ZJU',
#   'File Date': '08/20/2009',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['10/05/2009']},
#  {'Cause Number': '10-01-00148-DJU',
#   'File Date': '01/11/2010',
#   'Offense': ['MURDER'],
#   'Docket Date': [],
#   'Disposition Date': ['03/16/2010']},
#  {'Cause Number': '10-04-00218-ZJU',
#   'File Date': '04/14/2010',
#   'Offense': ['CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER',
#    'CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER',
#    'CONTEMPT OF COURT DISOBEDIENCE OF COURT ORDER'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '10-04-00220-ZJU',
#   'File Date': '04/29/2010',
#   'Offense': ['AGG ASSAULT CAUSES SERIOUS BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': ['08/12/2010']},
#  {'Cause Number': '11-02-00222-ZJU',
#   'File Date': '02/17/2011',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['04/05/2011']},
#  {'Cause Number': '11-07-00150-DJU',
#   'File Date': '07/21/2011',
#   'Offense': ['ASSAULT PUBLIC SERVANT'],
#   'Docket Date': [],
#   'Disposition Date': ['10/03/2011']},
#  {'Cause Number': '11-10-00224-ZJU',
#   'File Date': '10/18/2011',
#   'Offense': ['TERRORISTIC THREAT',
#    'ASSAULT CAUSES BODILY INJ',
#    'POSS MARIJ <2OZ',
#    'CHILD LABOR LAW',
#    'CHILD LABOR LAW',
#    'CHILD LABOR LAW'],
#   'Docket Date': [],
#   'Disposition Date': ['12/06/2011']},
#  {'Cause Number': '11-10-00226-ZJU',
#   'File Date': '10/26/2011',
#   'Offense': ['BURGLARY OF HABITATION', 'BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['12/06/2011']},
#  {'Cause Number': '11-10-00228-ZJU',
#   'File Date': '10/26/2011',
#   'Offense': ['BURGLARY OF HABITATION',
#    'BURGLARY OF HABITATION',
#    'BURGLARY OF HABITATION',
#    'BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['12/05/2011']},
#  {'Cause Number': '11-12-00152-DJU',
#   'File Date': '12/12/2011',
#   'Offense': ['BURGLARY OF VEHICLE'],
#   'Docket Date': [],
#   'Disposition Date': ['06/07/2013']},
#  {'Cause Number': '12-02-00154-DJU',
#   'File Date': '02/22/2012',
#   'Offense': ['POSS MARIJUANA <= 2 OZ'],
#   'Docket Date': [],
#   'Disposition Date': ['04/03/2012']},
#  {'Cause Number': '12-03-00230-ZJU',
#   'File Date': '03/16/2012',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': ['04/02/2012']},
#  {'Cause Number': '12-03-00232-ZJU',
#   'File Date': '03/16/2012',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': ['05/01/2012']},
#  {'Cause Number': '12-04-00234-ZJU',
#   'File Date': '04/02/2012',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': ['05/01/2012']},
#  {'Cause Number': '12-05-00156-DJU',
#   'File Date': '05/02/2012',
#   'Offense': ['BURGLARY OF VEHICLE'],
#   'Docket Date': [],
#   'Disposition Date': ['07/16/2013']},
#  {'Cause Number': '12-05-00158-DJU',
#   'File Date': '05/25/2012',
#   'Offense': ['THEFT PROP>=$50<$500'],
#   'Docket Date': [],
#   'Disposition Date': ['09/20/2013']},
#  {'Cause Number': '12-06-00160-DJU',
#   'File Date': '06/25/2012',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': ['11/02/2012']},
#  {'Cause Number': '12-06-00236-ZJU',
#   'File Date': '06/26/2012',
#   'Offense': ['EVADING ARREST DETENTION'],
#   'Docket Date': [],
#   'Disposition Date': ['09/04/2012']},
#  {'Cause Number': '12-08-00162-DJU',
#   'File Date': '08/16/2012',
#   'Offense': ['ASSLT CAUSES BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': ['05/30/2013']},
#  {'Cause Number': '12-10-00238-ZJU',
#   'File Date': '10/31/2012',
#   'Offense': ['CRIMINAL MISCHIEF >=$50<$500'],
#   'Docket Date': [],
#   'Disposition Date': ['01/02/2013']},
#  {'Cause Number': '12-12-00164-DJU',
#   'File Date': '12/17/2012',
#   'Offense': ['ASSLT CAUSES BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': ['03/08/2013']},
#  {'Cause Number': '13-01-00166-DJU',
#   'File Date': '01/31/2013',
#   'Offense': ['AGG ASSAULT CAUSES SERIOUS BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': ['11/18/2013']},
#  {'Cause Number': '13-03-00240-ZJU',
#   'File Date': '03/01/2013',
#   'Offense': ['ASSAULT CAUSES BODILY INJ', 'PROH WEAPON SWITCHBLADE/KNUCKLES'],
#   'Docket Date': [],
#   'Disposition Date': ['04/11/2013']},
#  {'Cause Number': '13-04-00242-ZJU',
#   'File Date': '04/24/2013',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['04/22/2013']},
#  {'Cause Number': '13-07-00244-ZJU',
#   'File Date': '07/02/2013',
#   'Offense': ['UNAUTH USE OF VEHICLE'],
#   'Docket Date': [],
#   'Disposition Date': ['07/17/2013']},
#  {'Cause Number': '14-02-00170-DJU',
#   'File Date': '02/13/2014',
#   'Offense': ['AGG ASSAULT CAUSES SERIOUS BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': ['06/03/2014']},
#  {'Cause Number': '14-04-00172-DJU',
#   'File Date': '04/08/2014',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': ['07/08/2014']},
#  {'Cause Number': '14-04-00174-DJU',
#   'File Date': '04/09/2014',
#   'Offense': ['ATTEMPTED BURGLARY OF A BUILDING',
#    'INDECENCY W/CHILD SEXUAL CONTACT'],
#   'Docket Date': [],
#   'Disposition Date': ['02/08/2016']},
#  {'Cause Number': '14-06-00176-DJU',
#   'File Date': '06/13/2014',
#   'Offense': ['AGG KIDNAPPING FOR RANSOM/REWARD'],
#   'Docket Date': [],
#   'Disposition Date': ['08/22/2014']},
#  {'Cause Number': '14-07-00246-ZJU',
#   'File Date': '07/08/2014',
#   'Offense': ['POSS MARIJ <2OZ'],
#   'Docket Date': [],
#   'Disposition Date': ['03/03/2015']},
#  {'Cause Number': '15-03-00486-MJU',
#   'File Date': '03/16/2015',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['07/07/2016']},
#  {'Cause Number': '15-05-00178-DJU',
#   'File Date': '05/29/2015',
#   'Offense': ['CRUELTY TO NON-LIVESTOCK ANIMALS: TORTURE'],
#   'Docket Date': [],
#   'Disposition Date': ['08/03/2015']},
#  {'Cause Number': '15-06-00496-MJU',
#   'File Date': '06/15/2015',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['01/07/2016']},
#  {'Cause Number': '15-07-00248-ZJU',
#   'File Date': '07/17/2015',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': ['11/04/2015']},
#  {'Cause Number': '15-07-00180-DJU',
#   'File Date': '07/30/2015',
#   'Offense': ['POSS CS PG 1 <1G'],
#   'Docket Date': [],
#   'Disposition Date': ['09/15/2016']},
#  {'Cause Number': '15-09-00182-DJU',
#   'File Date': '09/16/2015',
#   'Offense': ['POSS CS PG 1 >=4G<200G'],
#   'Docket Date': [],
#   'Disposition Date': ['11/09/2015']},
#  {'Cause Number': '15-10-00504-MJU',
#   'File Date': '10/06/2015',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['11/23/2015']},
#  {'Cause Number': '15-11-00508-MJU',
#   'File Date': '11/13/2015',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['05/08/2017']},
#  {'Cause Number': '15-12-00510-MJU',
#   'File Date': '12/11/2015',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['05/05/2016']},
#  {'Cause Number': '16-01-00250-ZJU',
#   'File Date': '01/06/2016',
#   'Offense': ['ABANDON/ENDANGER CHILD IMMINENT DANGER BI'],
#   'Docket Date': [],
#   'Disposition Date': ['04/05/2016']},
#  {'Cause Number': '16-02-00184-DJU',
#   'File Date': '02/23/2016',
#   'Offense': ['GRAFFITI PECUNIARY LOSS <$20K'],
#   'Docket Date': [],
#   'Disposition Date': ['05/03/2016']},
#  {'Cause Number': '16-04-00514-MJU',
#   'File Date': '04/04/2016',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['05/05/2016']},
#  {'Cause Number': '16-04-00516-MJU',
#   'File Date': '04/04/2016',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['01/05/2017']},
#  {'Cause Number': '16-04-00518-MJU',
#   'File Date': '04/19/2016',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['05/05/2016']},
#  {'Cause Number': '16-05-00186-DJU',
#   'File Date': '05/06/2016',
#   'Offense': ['DEADLY CONDUCT DISCHARGE FIREARM'],
#   'Docket Date': [],
#   'Disposition Date': ['05/22/2017']},
#  {'Cause Number': '16-07-00520-MJU',
#   'File Date': '07/07/2016',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['09/14/2017']},
#  {'Cause Number': '16-08-00526-MJU',
#   'File Date': '08/26/2016',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['08/02/2017']},
#  {'Cause Number': '16-10-00188-DJU',
#   'File Date': '10/04/2016',
#   'Offense': ['ASSAULT CAUSES BODILY INJURY FAMILY MEMBER'],
#   'Docket Date': [],
#   'Disposition Date': ['06/02/2017']},
#  {'Cause Number': '17-01-00252-ZJU',
#   'File Date': '01/12/2017',
#   'Offense': ['BURGLARY HABITATION INTEND OTHER FELONY'],
#   'Docket Date': [],
#   'Disposition Date': ['06/30/2017']},
#  {'Cause Number': '17-06-00528-MJU',
#   'File Date': '06/16/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['10/04/2017']},
#  {'Cause Number': '17-09-00190-DJU',
#   'File Date': '09/18/2017',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '17-10-00254-ZJU',
#   'File Date': '10/16/2017',
#   'Offense': ['ASSAULT CAUSES BODILY INJURY FAMILY MEMBER',
#    'THEFT PROP >=$2,500<$30K',
#    'INTERFER W/EMERGENCY REQ FOR ASSISTANCE',
#    'CRIMINAL MISCHIEF >=$100<$750',
#    'THEFT PROP >=$750<$2,500',
#    'ASSAULT CAUSES BODILY INJURY FAMILY MEMBER',
#    'CRIMINAL MISCHIEF >=$100<$750',
#    'ASSAULT CAUSES BODILY INJURY FAMILY MEMBER',
#    'CRIMINAL MISCHIEF >=$100<$750'],
#   'Docket Date': [],
#   'Disposition Date': ['12/04/2017']},
#  {'Cause Number': '17-10-00530-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['01/05/2018']},
#  {'Cause Number': '17-10-00532-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['11/30/2018']},
#  {'Cause Number': '17-10-00534-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['08/01/2018']},
#  {'Cause Number': '17-10-00536-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['07/06/2018']},
#  {'Cause Number': '17-10-00538-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['08/01/2018']},
#  {'Cause Number': '17-10-00540-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['05/31/2018']},
#  {'Cause Number': '17-10-00542-MJU',
#   'File Date': '10/23/2017',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['06/25/2018']},
#  {'Cause Number': '18-02-00544-MJU',
#   'File Date': '02/26/2018',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['08/01/2018']},
#  {'Cause Number': '18-04-00546-MJU',
#   'File Date': '04/06/2018',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['12/12/2018']},
#  {'Cause Number': '18-05-00192-DJU',
#   'File Date': '05/07/2018',
#   'Offense': ['BURGLARY OF BLDNG ENTER/CONCEAL INTND THEFT CS'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '18-06-00548-MJU',
#   'File Date': '06/07/2018',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['09/06/2018']},
#  {'Cause Number': '18-08-00550-MJU',
#   'File Date': '08/02/2018',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['04/18/2019']},
#  {'Cause Number': '18-10-00256-ZJU',
#   'File Date': '10/30/2018',
#   'Offense': ['FALSE ALARM OR REPORT'],
#   'Docket Date': [],
#   'Disposition Date': ['12/26/2018']},
#  {'Cause Number': '18-11-00194-DJU',
#   'File Date': '11/08/2018',
#   'Offense': ['CRIM MISCH $200<$750'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '18-11-00552-MJU',
#   'File Date': '11/16/2018',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['04/05/2019']},
#  {'Cause Number': '19-01-00554-MJU',
#   'File Date': '01/10/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['02/20/2019']},
#  {'Cause Number': '19-02-00556-MJU',
#   'File Date': '02/07/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['06/07/2019']},
#  {'Cause Number': '19-03-00558-MJU',
#   'File Date': '03/20/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-03-00258-ZJU',
#   'File Date': '04/01/2019',
#   'Offense': ['MURDER'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-04-00560-MJU',
#   'File Date': '04/08/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['06/07/2019']},
#  {'Cause Number': '19-07-00260-ZJU',
#   'File Date': '07/02/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-07-00562-MJU',
#   'File Date': '07/09/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['11/15/2019']},
#  {'Cause Number': '19-08-00564-MJU',
#   'File Date': '08/29/2019',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-10-00196-DJU',
#   'File Date': '10/08/2019',
#   'Offense': ['BURGLARY OF BUILDING'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-10-00198-DJU',
#   'File Date': '10/08/2019',
#   'Offense': ['BURGLARY OF HABITATION'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-10-0200-DJU',
#   'File Date': '10/08/2019',
#   'Offense': ['ASSAULT CAUSES BODILY INJURY FAMILY MEMBER ENH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '19-11-0202-DJU',
#   'File Date': '11/20/2019',
#   'Offense': ['EVADING ARREST DET W/VEH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '20-01-00566-MJU',
#   'File Date': '01/09/2020',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': ['03/02/2020']},
#  {'Cause Number': '20-02-00568-MJU',
#   'File Date': '02/26/2020',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '20-05-00570-MJU',
#   'File Date': '05/14/2020',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '20-05-00262-ZJU',
#   'File Date': '05/20/2020',
#   'Offense': ['AGG ASSAULT W/DEADLY WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '20-10-0204-DJU',
#   'File Date': '10/14/2020',
#   'Offense': ['AGG SEXUAL ASSAULT CHILD'],
#   'Docket Date': [],
#   'Disposition Date': ['01/17/2022']},
#  {'Cause Number': '20-11-0206-DJU',
#   'File Date': '11/10/2020',
#   'Offense': ['PROH SEXUAL CONDUCT'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-03-00264-ZJU',
#   'File Date': '03/04/2021',
#   'Offense': ['ASSAULT CAUSES BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-05-00572-MJU',
#   'File Date': '05/12/2021',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-09-00574-MJU',
#   'File Date': '09/24/2021',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-12-00576-MJU',
#   'File Date': '12/07/2021',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-12-00266-ZJU',
#   'File Date': '12/10/2021',
#   'Offense': ['EVADING ARREST DETENTION W/VEH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '21-12-0208-DJU',
#   'File Date': '12/30/2021',
#   'Offense': ['UNL CARRYING WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-03-00578-MJU',
#   'File Date': '03/28/2022',
#   'Offense': ['HARASSMENT'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-03-0210-DJU',
#   'File Date': '03/30/2022',
#   'Offense': ['UNL CARRYING WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-05-0212-DJU',
#   'File Date': '05/27/2022',
#   'Offense': ['SMUGGLING OF PERSONS'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-06-0214-DJU',
#   'File Date': '06/16/2022',
#   'Offense': ['EVADING ARREST DET W/VEH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-07-00580-MJU',
#   'File Date': '07/22/2022',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-08-DAVIN-MJU',
#   'File Date': '08/29/2022',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-09-JUANH-MJU',
#   'File Date': '09/06/2022',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-10-00582-MJU',
#   'File Date': '10/14/2022',
#   'Offense': ['AGG ROBBERY'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-11-JUANP-MJU',
#   'File Date': '11/04/2022',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-11-ALEXA-MJU',
#   'File Date': '11/16/2022',
#   'Offense': [],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-11-00584-MJU',
#   'File Date': '11/16/2022',
#   'Offense': ['EVADING ARREST DETENTION',
#    'CRIMINAL MISCHIEF >=$100<$750',
#    'EVADING ARREST DET W/VEH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-12-0216-DJU',
#   'File Date': '12/15/2022',
#   'Offense': ['UNL CARRYING WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '22-12-0218-DJU',
#   'File Date': '12/22/2022',
#   'Offense': ['UNL CARRYING WEAPON'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-03-0220-DJU',
#   'File Date': '03/06/2023',
#   'Offense': ['EVADING ARREST/DET USING VEH'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-02-00586-MJU',
#   'File Date': '03/06/2023',
#   'Offense': ['POSS CS PG 1 >=1G<4G'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-03-00588-MJU',
#   'File Date': '03/27/2023',
#   'Offense': ['ASSAULT CAUSES BODILY INJ', 'EVADING ARREST DETENTION'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-05-0222-DJU',
#   'File Date': '05/04/2023',
#   'Offense': ['UNAUTH USE OF VEHICLE'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-05-00590-MJU',
#   'File Date': '05/08/2023',
#   'Offense': ['ASSAULT PEACE OFFICER/JUDGE', 'EVADING ARREST DET W/VEH'],
#   'Docket Date': ['06/03/2024'],
#   'Disposition Date': []},
#  {'Cause Number': '23-07-0224-DJU',
#   'File Date': '07/26/2023',
#   'Offense': ['SMUGGLING OF PERSONS: FIREARM'],
#   'Docket Date': [],
#   'Disposition Date': []},
#  {'Cause Number': '23-07-00592-MJU',
#   'File Date': '07/29/2023',
#   'Offense': ['EVADING ARREST DET W/VEH'],
#   'Docket Date': ['04/04/2024'],
#   'Disposition Date': []},
#  {'Cause Number': '23-10-0226-DJU',
#   'File Date': '10/19/2023',
#   'Offense': ['AGG ASSAULT CAUSES SERIOUS BODILY INJ'],
#   'Docket Date': [],
#   'Disposition Date': []}]

# %%
df = pd.DataFrame(case_list)
df
# Out:
#         Cause Number   File Date  \
# 0    08-03-00134-DJU  03/20/2008
# 1    08-10-00208-ZJU  10/21/2008
# 2    09-03-00212-ZJU  03/09/2009
# 3    09-07-00146-DJU  07/30/2009
# 4    09-08-00214-ZJU  08/20/2009
# ..               ...         ...
# 112   23-05-0222-DJU  05/04/2023
# 113  23-05-00590-MJU  05/08/2023
# 114   23-07-0224-DJU  07/26/2023
# 115  23-07-00592-MJU  07/29/2023
# 116   23-10-0226-DJU  10/19/2023
#
#                                                Offense   Docket Date  \
# 0                        [AGG ASSAULT W/DEADLY WEAPON]            []
# 1                             [BURGLARY OF HABITATION]            []
# 2    [CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE]            []
# 3                               [BURGLARY OF BUILDING]            []
# 4                             [BURGLARY OF HABITATION]            []
# ..                                                 ...           ...
# 112                            [UNAUTH USE OF VEHICLE]            []
# 113  [ASSAULT PEACE OFFICER/JUDGE, EVADING ARREST D...  [06/03/2024]
# 114                    [SMUGGLING OF PERSONS: FIREARM]            []
# 115                         [EVADING ARREST DET W/VEH]  [04/04/2024]
# 116            [AGG ASSAULT CAUSES SERIOUS BODILY INJ]            []
#
#     Disposition Date
# 0                 []
# 1                 []
# 2       [06/10/2009]
# 3                 []
# 4       [10/05/2009]
# ..               ...
# 112               []
# 113               []
# 114               []
# 115               []
# 116               []
#
# [117 rows x 5 columns]

# %% [markdown]
# # Build the Function

# %%
def extract_juvenile_cases(text):
    """
    This function takes in the entire PDF document as a string of text. It will gather the info for each case
    and add the info to a dictionary. The dictionary for each case will be added to a list which will be turned into
    a dataframe.
    
    Parameter:
        -text: A string consisting of the text of the entire juvenile cases PDF document.
        
    Returns:
        -df: A dataframe of the newly gathered juvenile case info
    """
    
    #Initialize containers
    #Establish a container list for the dictionaries
    case_list = []
    offense_list = []
    docket_date_list = []
    dispo_date_list = []
    temp_dict = {}
    
    #Get the header and remove surrounding whitespace
    header = text[:450].strip()

    #Get the body and remove surrounding whitespace
    body = text[450:].strip()
    
    #Get the 'AS OF' date:
    report_as_of_date = re.findall(r"[0-9]{2}/[0-9]{2}/[0-9]{4}", header)[0]
        
    #Set up regex to remove all subsequent headers
    #This regex should identify the headers even if some of the info changes later on
    body = re.sub(r"""\n\x0c\s*[A-Z0-9 \(\)\n/#\:-]*\.\sDATE""", '', body)
    
    #Split the text on the \n to isolate each case
    cases = body.split('\n')
    
    #Drop the last case. It's just the total case count from the report
    cases.pop()
    
    #Remove cases that happen to be empty or consist of whitespace only
    cases = [case for case in cases if case.isspace() == False and len(case) > 0]
    
    #Loop through each line. Add case info to temp dict, and then add that to the case list
    #Some fields are commented out because we don't need that info yet.
    for line in cases:
        if line.isspace() or len(line) == 0:
            continue

        #Check if line is the start of a new case
        if not line[0].isspace():
            #Check if the temp_dict is empty.
            #If not, add temp_dict data to case_list
            if bool(temp_dict) == True:
                #Add list info to temp_dict
                temp_dict['Offense'] = offense_list
                temp_dict['Docket Date'] = docket_date_list
                temp_dict['Disposition Date'] = dispo_date_list

                #Add temp dict data to case_list
                case_list.append(temp_dict)

            #Reset temp_dict
            temp_dict = {}

            #Reset lists
            offense_list = []
            docket_date_list = []
            dispo_date_list = []

            #Gather the cause number
            temp_dict['Cause Number'] = line[9:26].strip()

            #Gather the file date
            temp_dict['File Date'] = line[26:38].strip()

            #Get court
            #temp_dict['Court'] = line[38:70].strip()

            #Get respondent
            #temp_dict['Respondent'] = line[70:].strip()

            #End of line, so move to next one

        else:
            #Get offenses
            offense = line[5:88].strip()

            #Check if offense is all whitesapace. If not, strip it and add to list
            #Also check that the string is not empty
            if offense.isspace() == False and len(offense) > 0:
                offense_list.append(offense.strip())

            #Get Docket Date
            docket_date = line[88:98].strip()

            #Check if offense is all whitesapace. If not, strip it and add to list
            #Also check that the string is not empty
            if docket_date.isspace() == False and len(docket_date) > 0:
                docket_date_list.append(docket_date.strip())

            #Get Disposition Date
            dispo_date = line[98:].strip()

            #Check if offense is all whitesapace. If not, strip it and add to list
            #Also check that the string is not empty
            if dispo_date.isspace() == False and len(dispo_date) > 0:
                dispo_date_list.append(dispo_date.strip())

            #End of line
        
    #Check that the last case was added to the list
    #Add list info to temp_dict
    temp_dict['Offense'] = offense_list
    temp_dict['Docket Date'] = docket_date_list
    temp_dict['Disposition Date'] = dispo_date_list

    #Add temp dict data to case_list
    case_list.append(temp_dict)
    
    #How many?
    print(f'Collected Data From {len(case_list)} Cases.')
    
    #Create dataframe
    df = pd.DataFrame(case_list)
    
    #Add report as of date
    df["Original As Of Date"] = report_as_of_date
    df["Last As Of Date"] = report_as_of_date
    df["Report Generated Date"] = report_as_of_date
    
    return df

# %% [markdown]
# # Test Function

# %%
#Set up the pdf path
pdf_path = '/Users/johnathonsmith/Downloads/24_01_22_DJU MJU ZJU _ All Counties.pdf'

# %%
#Set up resource manager to handle pdf content. text, images, etc.
resource_manager = PDFResourceManager()

#Used to display text
fake_file_handle = io.StringIO()

#Set up converter
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())

#Set up page interpreter
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open(pdf_path, 'rb') as fh:

    for page_num, page in enumerate(PDFPage.get_pages(fh, caching=True, check_extractable=True)):
        #Process the current page
        page_interpreter.process_page(page)

    #Save the current page's text to a variable
    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

#print(text)

# %%
df = extract_juvenile_cases(text)
# Out:
# Collected Data From 117 Cases.

# %%
df
# Out:
#         Cause Number   File Date  \
# 0    08-03-00134-DJU  03/20/2008
# 1    08-10-00208-ZJU  10/21/2008
# 2    09-03-00212-ZJU  03/09/2009
# 3    09-07-00146-DJU  07/30/2009
# 4    09-08-00214-ZJU  08/20/2009
# ..               ...         ...
# 112   23-05-0222-DJU  05/04/2023
# 113  23-05-00590-MJU  05/08/2023
# 114   23-07-0224-DJU  07/26/2023
# 115  23-07-00592-MJU  07/29/2023
# 116   23-10-0226-DJU  10/19/2023
#
#                                                Offense   Docket Date  \
# 0                        [AGG ASSAULT W/DEADLY WEAPON]            []
# 1                             [BURGLARY OF HABITATION]            []
# 2    [CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE]            []
# 3                               [BURGLARY OF BUILDING]            []
# 4                             [BURGLARY OF HABITATION]            []
# ..                                                 ...           ...
# 112                            [UNAUTH USE OF VEHICLE]            []
# 113  [ASSAULT PEACE OFFICER/JUDGE, EVADING ARREST D...  [06/03/2024]
# 114                    [SMUGGLING OF PERSONS: FIREARM]            []
# 115                         [EVADING ARREST DET W/VEH]  [04/04/2024]
# 116            [AGG ASSAULT CAUSES SERIOUS BODILY INJ]            []
#
#     Disposition Date Original As Of Date Last As Of Date Report Generated Date
# 0                 []          01/22/2024      01/22/2024            01/22/2024
# 1                 []          01/22/2024      01/22/2024            01/22/2024
# 2       [06/10/2009]          01/22/2024      01/22/2024            01/22/2024
# 3                 []          01/22/2024      01/22/2024            01/22/2024
# 4       [10/05/2009]          01/22/2024      01/22/2024            01/22/2024
# ..               ...                 ...             ...                   ...
# 112               []          01/22/2024      01/22/2024            01/22/2024
# 113               []          01/22/2024      01/22/2024            01/22/2024
# 114               []          01/22/2024      01/22/2024            01/22/2024
# 115               []          01/22/2024      01/22/2024            01/22/2024
# 116               []          01/22/2024      01/22/2024            01/22/2024
#
# [117 rows x 8 columns]

# %% [markdown]
# # Prepare Dataframe
#
# __Get County__
#
# The juvenile case report contains cases for all three counties, so I'll need to apply a function to determine the county based on the Cause Number.

# %%
def get_juvenile_case_county(cause_number):
    """
    The juvenile case report contains cases for all three counties,
    so I'll need to apply a function to determine the county based on the Cause Number.
    
    Parameter:
        - cause_number: A string representing the case cause number.
        
    Returns:
        - county: A string representing the county the case belongs to.
    """
    
    #Get the final section of text in the cause number
    final_section = cause_number[11:]
    
    if final_section.count('MJU') == 1:
        return 'Maverick'
    elif final_section.count('DJU') == 1:
        return 'Dimmit'
    elif final_section.count('ZJU') == 1:
        return 'Zavala'

# %%
#Test county function
df['County'] = df['Cause Number'].apply(get_juvenile_case_county)
df
# Out:
#         Cause Number   File Date  \
# 0    08-03-00134-DJU  03/20/2008
# 1    08-10-00208-ZJU  10/21/2008
# 2    09-03-00212-ZJU  03/09/2009
# 3    09-07-00146-DJU  07/30/2009
# 4    09-08-00214-ZJU  08/20/2009
# ..               ...         ...
# 112   23-05-0222-DJU  05/04/2023
# 113  23-05-00590-MJU  05/08/2023
# 114   23-07-0224-DJU  07/26/2023
# 115  23-07-00592-MJU  07/29/2023
# 116   23-10-0226-DJU  10/19/2023
#
#                                                Offense   Docket Date  \
# 0                        [AGG ASSAULT W/DEADLY WEAPON]            []
# 1                             [BURGLARY OF HABITATION]            []
# 2    [CRIM MISCH <$1,500 HAB DAMAGE FIREARM/EXPLOSIVE]            []
# 3                               [BURGLARY OF BUILDING]            []
# 4                             [BURGLARY OF HABITATION]            []
# ..                                                 ...           ...
# 112                            [UNAUTH USE OF VEHICLE]            []
# 113  [ASSAULT PEACE OFFICER/JUDGE, EVADING ARREST D...  [06/03/2024]
# 114                    [SMUGGLING OF PERSONS: FIREARM]            []
# 115                         [EVADING ARREST DET W/VEH]  [04/04/2024]
# 116            [AGG ASSAULT CAUSES SERIOUS BODILY INJ]            []
#
#     Disposition Date Original As Of Date Last As Of Date  \
# 0                 []          01/22/2024      01/22/2024
# 1                 []          01/22/2024      01/22/2024
# 2       [06/10/2009]          01/22/2024      01/22/2024
# 3                 []          01/22/2024      01/22/2024
# 4       [10/05/2009]          01/22/2024      01/22/2024
# ..               ...                 ...             ...
# 112               []          01/22/2024      01/22/2024
# 113               []          01/22/2024      01/22/2024
# 114               []          01/22/2024      01/22/2024
# 115               []          01/22/2024      01/22/2024
# 116               []          01/22/2024      01/22/2024
#
#     Report Generated Date    County
# 0              01/22/2024    Dimmit
# 1              01/22/2024    Zavala
# 2              01/22/2024    Zavala
# 3              01/22/2024    Dimmit
# 4              01/22/2024    Zavala
# ..                    ...       ...
# 112            01/22/2024    Dimmit
# 113            01/22/2024  Maverick
# 114            01/22/2024    Dimmit
# 115            01/22/2024  Maverick
# 116            01/22/2024    Dimmit
#
# [117 rows x 9 columns]
