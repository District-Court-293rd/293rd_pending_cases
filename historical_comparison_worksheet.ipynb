# %%
import numpy as np
import pandas as pd
import re
from datetime import date

# %%
#Create open criminal case df
open_cases = pd.read_csv('/Users/johnathonsmith/Downloads/Pending Reports - test_criminal_cases.csv')

# %%
open_cases.head()
# Out:
#    County     Cause Number   File Date  Docket Date       Defendant Name  \
# 0  Dimmit  02-10-02242-DCR  10/03/2005          NaN      MONTOYA, ROBERT
# 1  Dimmit  05-12-02334-DCR  10/07/2008          NaN  GERDES, ANDREW JOHN
# 2  Dimmit  06-06-02372-DCR  06/21/2010          NaN     TITSWORTH, DAVID
# 3  Dimmit  08-11-02464-DCR  08/26/2015          NaN   MERTZ, MELISSA ANN
# 4  Dimmit  09-08-02510-DCR  04/21/2015          NaN       HURTADO, ANGEL
#
#      Attorney Name Bondsman Name                      Offense Case Type  \
# 0  CABELLO, RUFINO           NaN             POSS CS PG 1 <1G  Criminal
# 1  JOHNSON, CHARLE           NaN      THEFT PROP >=$20K<$100K  Criminal
# 2  CABELLO, RUFINO           NaN             POSS CS PG 1 <1G  Criminal
# 3   PONCE, MICHAEL           NaN      THEFT PROP>=$1,500<$20K  Criminal
# 4  RODRIGUEZ, JR.,           NaN  POSS MARIJ >50LBS<=2,000LBS  Criminal
#
#    On Track Months Ahead Or Behind  Bad Cause Number Status  Closed Date
# ...

# %%
#Replace NaN with empty string
open_cases.fillna('', inplace = True)

# %%
open_cases.head()
# Out:
#    County     Cause Number   File Date Docket Date       Defendant Name  \
# 0  Dimmit  02-10-02242-DCR  10/03/2005                  MONTOYA, ROBERT
# 1  Dimmit  05-12-02334-DCR  10/07/2008              GERDES, ANDREW JOHN
# 2  Dimmit  06-06-02372-DCR  06/21/2010                 TITSWORTH, DAVID
# 3  Dimmit  08-11-02464-DCR  08/26/2015               MERTZ, MELISSA ANN
# 4  Dimmit  09-08-02510-DCR  04/21/2015                   HURTADO, ANGEL
#
#      Attorney Name Bondsman Name                      Offense Case Type  \
# 0  CABELLO, RUFINO                           POSS CS PG 1 <1G  Criminal
# 1  JOHNSON, CHARLE                    THEFT PROP >=$20K<$100K  Criminal
# 2  CABELLO, RUFINO                           POSS CS PG 1 <1G  Criminal
# 3   PONCE, MICHAEL                    THEFT PROP>=$1,500<$20K  Criminal
# 4  RODRIGUEZ, JR.,                POSS MARIJ >50LBS<=2,000LBS  Criminal
#
#    On Track Months Ahead Or Behind  Bad Cause Number Status Closed Date
# ...

# %%
#Add new column for date uploaded. Just use today's date
open_cases['Load Date'] = str(date.today())

# %%
# Out:
#      County     Cause Number   File Date Docket Date          Defendant Name  \
# 0    Dimmit  02-10-02242-DCR  10/03/2005                     MONTOYA, ROBERT
# 1    Dimmit  05-12-02334-DCR  10/07/2008                 GERDES, ANDREW JOHN
# 2    Dimmit  06-06-02372-DCR  06/21/2010                    TITSWORTH, DAVID
# 3    Dimmit  08-11-02464-DCR  08/26/2015                  MERTZ, MELISSA ANN
# 4    Dimmit  09-08-02510-DCR  04/21/2015                      HURTADO, ANGEL
# ..      ...              ...         ...         ...                     ...
# 122  Zavala  21-11-03892-ZCR  11/18/2021                MITCHELL, KARLA RENE
# 123  Zavala  22-03-03898-ZCR  03/04/2022                  AGUERO, JOHN PEDRO
# 124  Zavala  22-03-03900-ZCR  03/04/2022              MACHADO, MARTHA CORTEZ
# 125  Zavala  22-03-03906-ZCR  03/04/2022                        BEDELL, GAGE
# 126  Zavala  96-04-02608-ZCR  04/19/1996              POMPA-CONTRERAS, JESUS
#
# ...
